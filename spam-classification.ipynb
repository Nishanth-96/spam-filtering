# %%
import numpy as np
import os 
import re
import pickle
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
def process_content(content,output):
    content = content.lower()    
    content = re.sub('<[^>]*>','',content)
    content = content.replace('&nbsp','')
    content = re.sub('(http|https)://[^\s]*','httpaddr',content)
    content = re.sub('[0-9]+','number',content)
    content = re.sub('[$]+','dollar',content)
    content = re.sub('[^\s]+@[^\s]+','emailaddr',content)
    
    words = word_tokenize(content)
    ps = PorterStemmer()
    all_words = []
    for word in words:
        all_words.append(ps.stem(word))
    
    content = " ".join(all_words)
    with open(output, 'w+') as output_file:
        output_file.write(content)

# %%
def preprocess_email(files_dir,mail_type,split_rate):
    f_count = len(os.listdir(spam_dir))
    train_count = int(f_count * split_rate)
    files = [os.path.join(files_dir,f) for f in os.listdir(files_dir)]
    content = []
    for file in files[:train_count]:
        with open(file, errors='ignore') as f:
            for line in f:
                if line in ['\n','\r\n']:
                    break
                
            content = f.read()
            content = content.lower()
            output = 'preprocessed-files/train-mails/' + mail_type + file.split('/')[-1]                
            content = process_content(content,output)
     
    for file in files[train_count:]:
        with open(file, errors='ignore') as f:
            for line in f:
                if line in ['\n','\r\n']:
                    break
                
            content = f.read()
            output = 'preprocessed-files/test-mails/' + mail_type + file.split('/')[-1]
            content = content.lower()
            content = process_content(content,output)

# %%
def extract_features(mail_dir,vocab):
    files = [os.path.join(mail_dir,f) for f in os.listdir(mail_dir)]
    features = np.zeros((len(files),len(vocab)))
    y = []
    fileID = 0
    count = 0
    for f in files:
        with open(f,'r') as fi:
            text = fi.read()
            words = text.split()
            for word in words:
                for wordID,d in enumerate(vocab):
                    if word == d:
                        features[fileID,wordID] = words.count(word)
                        break      
            fi.close()
            fileID = fileID + 1
      
        if f.split("/")[-1].startswith('spam'):
            y.append(1)
        else:
            y.append(0)
                       
    return features,y

# %%
from collections import Counter
def make_vocabulary():
    files = []
    mail_dir = 'preprocessed-files/train-mails/'
    for f in os.listdir(mail_dir):
        if f.startswith('spam'):
            files.append(os.path.join(mail_dir,f))
    words = []
    for file in files:
        with open(file, errors='ignore') as f:
            content = f.read()
            words += content.split()
            
    vocab = Counter(words).most_common(5000)
    return vocab

# %%
import nltk
def clean_vocabulary(vocabulary):
    dictionary = dict(vocabulary)
    stop_words = set(stopwords.words('english'))
    
    for key in list(dictionary.keys()):
        if len(key)==1:
            del dictionary[key]
        elif not key.isalpha():
            del dictionary[key]
        elif key in stop_words:
            del dictionary[key]
            
    return dictionary

# %% [markdown]
# #### Preprocessing mails

# %%
spam_dir = 'dataset/spam_2'
ham_dir = 'dataset/easy_ham_2'

train_directory = 'preprocessed-files/train-mails'
if not os.path.exists(train_directory):
    os.makedirs(train_directory)

test_directory = 'preprocessed-files/test-mails'
if not os.path.exists(test_directory):
    os.makedirs(test_directory)

# %%
preprocess_email(spam_dir,'spam.',0.8)
preprocess_email(ham_dir,'ham.',0.8)

# %% [markdown]
# #### Vocabulary for spam words

# %%
spam_vocabulary = make_vocabulary()
print(spam_vocabulary)
# Out:
# [(',', 16836), ('--', 16088), ('.', 14212), ('the', 11850), ('to', 11301), ('number', 11042), (';', 9505), ('and', 8291), ('you', 8113), ('of', 6914), ('!', 6366), ('a', 6243), ('%', 6008), (':', 5599), ('your', 5381), ('for', 4775), ('in', 4417), ('is', 3989), ('thi', 3864), ('#', 2970), ('it', 2609), ('be', 2530), (')', 2510), ('or', 2448), ('=', 2427), ('i', 2409), ('on', 2386), ('with', 2386), ('(', 2362), ('are', 2359), ('that', 2351), ('=number', 2270), ('we', 2220), ('will', 2157), ('-', 2125), ("''", 2105), ('httpaddr', 2066), ('our', 2011), ('have', 1985), ('&', 1953), ('email', 1913), ('from', 1861), ('not', 1728), ('free', 1609), ('...', 1607), ('by', 1602), ('if', 1567), ('do', 1556), ('as', 1541), ('can', 1532), ('all', 1470), ('click', 1389), ('?', 1326), ('at', 1322), ('dollarnumb', 1300), ('here', 1296), ('get', 1243), ('list', 1240), ("'s", 1186), ('busi', 1180), ('no', 1160), ('receiv', 1154), ('more', 1146), ('pleas', 1106), ('mail', 1068), ('order', 1028), ('remov', 1022), ('``', 990), ('an', 981), ('address', 971), ('out', 963), ('dollarnumber.numb', 914), ('one', 910), ('money', 906), ('use', 905), ('inform', 888), ('emailaddr', 886), ('my', 884), ('anumb', 871), ('>', 827), ("n't", 820), ('onli', 807), ('site', 800), ('make', 800), ('now', 780), ('time', 775), ('send', 772), ('us', 772), ('just', 752), ('e-mail', 745), ('program', 728), ('how', 721), ('peopl', 716), ('offer', 705), ('ani', 698), ('new', 697), ('name', 683), ('product', 664), ('work', 663), ('up', 634), ('want', 627), ('compani', 623), ('servic', 617), ('wa', 616), ('they', 615), ('so', 614), ('what', 606), ('about', 601), ('fnumber', 598), ('internet', 593), ('ha', 584), ('number.numb', 580), ('day', 579), ('market', 578), ('call', 575), ('need', 572), ('report', 570), ('over', 559), ('*', 556), ('grant', 553), ('home', 551), ('credit', 542), ('messag', 539), ('like', 527), ('web', 524), ('year', 521), ('includ', 513), ('quot', 502), ('state', 498), ('there', 490), ('may', 486), ('me', 485), ('rate', 476), ('who', 469), ('other', 469), ('but', 469), ('help', 464), ('would', 463), ('them', 460), ('these', 455), ('price', 449), ('month', 448), ('below', 446), ('than', 446), ('also', 432), ('been', 428), ('million', 427), ('form', 423), ('enumb', 422), ('their', 419), ('ad', 416), ('dollar', 415), ('phone', 413), ('govern', 411), ('number-numb', 403), ('today', 402), ('find', 400), ('which', 387), ('link', 385), ('when', 385), ('onlin', 384), ('person', 382), ('go', 380), ('best', 378), ('softwar', 378), ('start', 375), ('first', 370), ('save', 369), ('then', 366), ('interest', 366), ('most', 365), ('guarante', 360), ('provid', 360), ('avail', 359), ('life', 358), ('follow', 357), ('take', 356), ('check', 351), ('into', 350), ('see', 349), ('even', 347), ('each', 347), ('doe', 345), ('am', 345), ('special', 344), ('everi', 343), ('right', 342), ('mani', 342), ('know', 340), ('system', 340), ('subject', 337), ('search', 337), ('look', 336), ('card', 335), ('repli', 334), ('websit', 333), ('much', 330), ('advertis', 329), ('content-typ', 328), ('way', 325), ('per', 323), ('complet', 322), ('contact', 322), ('visit', 321), ('custom', 321), ('becaus', 317), ('within', 317), ('veri', 316), ('page', 315), ('cost', 314), ('sale', 311), ('insur', 307), ('futur', 303), ('own', 303), ('color=numberd', 302), ('de', 301), ('invest', 296), ('wish', 296), ('week', 294), ('profession', 289), ('world', 286), ('success', 284), ('content-transfer-encod', 283), ('secur', 279), ('back', 277), ('opportun', 276), ('unsubscrib', 276), ('hour', 276), ('some', 275), ('purchas', 274), ('account', 272), ('easi', 270), ('sent', 266), ('give', 264), ('sell', 261), ('through', 261), ('thank', 258), ('come', 256), ('fax', 251), ('amp', 251), ('could', 249), ("'", 248), ('legal', 246), ('commun', 244), ('low', 244), ('financi', 239), ('good', 238), ('}', 238), ('access', 237), ('increas', 236), ("'ll", 236), ('read', 234), ('after', 233), ('chang', 232), ('pay', 232), ('h ...

# %% [markdown]
# #### Cleaning the vocabulary

# %%
spam_vocabulary = clean_vocabulary(spam_vocabulary)
print(spam_vocabulary)
# Out:
# {'number': 11042, 'thi': 3864, 'httpaddr': 2066, 'email': 1913, 'free': 1609, 'click': 1389, 'dollarnumb': 1300, 'get': 1243, 'list': 1240, 'busi': 1180, 'receiv': 1154, 'pleas': 1106, 'mail': 1068, 'order': 1028, 'remov': 1022, 'address': 971, 'one': 910, 'money': 906, 'use': 905, 'inform': 888, 'emailaddr': 886, 'anumb': 871, 'onli': 807, 'site': 800, 'make': 800, 'time': 775, 'send': 772, 'us': 772, 'program': 728, 'peopl': 716, 'offer': 705, 'ani': 698, 'new': 697, 'name': 683, 'product': 664, 'work': 663, 'want': 627, 'compani': 623, 'servic': 617, 'wa': 616, 'fnumber': 598, 'internet': 593, 'ha': 584, 'day': 579, 'market': 578, 'call': 575, 'need': 572, 'report': 570, 'grant': 553, 'home': 551, 'credit': 542, 'messag': 539, 'like': 527, 'web': 524, 'year': 521, 'includ': 513, 'quot': 502, 'state': 498, 'may': 486, 'rate': 476, 'help': 464, 'would': 463, 'price': 449, 'month': 448, 'also': 432, 'million': 427, 'form': 423, 'enumb': 422, 'ad': 416, 'dollar': 415, 'phone': 413, 'govern': 411, 'today': 402, 'find': 400, 'link': 385, 'onlin': 384, 'person': 382, 'go': 380, 'best': 378, 'softwar': 378, 'start': 375, 'first': 370, 'save': 369, 'interest': 366, 'guarante': 360, 'provid': 360, 'avail': 359, 'life': 358, 'follow': 357, 'take': 356, 'check': 351, 'see': 349, 'even': 347, 'doe': 345, 'special': 344, 'everi': 343, 'right': 342, 'mani': 342, 'know': 340, 'system': 340, 'subject': 337, 'search': 337, 'look': 336, 'card': 335, 'repli': 334, 'websit': 333, 'much': 330, 'advertis': 329, 'way': 325, 'per': 323, 'complet': 322, 'contact': 322, 'visit': 321, 'custom': 321, 'becaus': 317, 'within': 317, 'veri': 316, 'page': 315, 'cost': 314, 'sale': 311, 'insur': 307, 'futur': 303, 'de': 301, 'invest': 296, 'wish': 296, 'week': 294, 'profession': 289, 'world': 286, 'success': 284, 'secur': 279, 'back': 277, 'opportun': 276, 'unsubscrib': 276, 'hour': 276, 'purchas': 274, 'account': 272, 'easi': 270, 'sent': 266, 'give': 264, 'sell': 261, 'thank': 258, 'come': 256, 'fax': 251, 'amp': 251, 'could': 249, 'legal': 246, 'commun': 244, 'low': 244, 'financi': 239, 'good': 238, 'access': 237, 'increas': 236, 'read': 234, 'chang': 232, 'pay': 232, 'hi': 232, 'fill': 231, 'line': 231, 'made': 230, 'without': 227, 'never': 226, 'cd': 226, 'comput': 226, 'cash': 225, 'respons': 223, 'letter': 221, 'age': 219, 'improv': 218, 'minut': 217, 'question': 216, 'keep': 216, 'heaven': 213, 'loan': 212, 'request': 212, 'simpli': 209, 'gener': 207, 'let': 207, 'member': 206, 'result': 203, 'place': 203, 'build': 201, 'buy': 201, 'tri': 201, 'whi': 200, 'base': 200, 'bnumber': 199, 'manag': 197, 'incom': 197, 'anyon': 196, 'lead': 195, 'current': 195, 'simpl': 194, 'step': 194, 'befor': 193, 'packag': 192, 'long': 192, 'instruct': 192, 'requir': 192, 'color': 192, 'great': 191, 'guid': 191, 'ever': 190, 'trade': 190, 'engin': 188, 'copi': 187, 'plan': 187, 'mortgag': 186, 'secret': 186, 'say': 185, 'famili': 185, 'ship': 185, 'countri': 183, 'broadcast': 183, 'toner': 182, 'numbera': 181, 'top': 180, 'lose': 180, 'full': 179, 'high': 179, 'risk': 178, 'thousand': 177, 'unit': 176, 'power': 176, 'sponsor': 176, 'write': 175, 'next': 175, 'less': 174, 'applic': 173, 'real': 171, 'detail': 170, 'think': 170, 'show': 170, 'cartridg': 170, 'process': 168, 'problem': 166, 'develop': 166, 'appli': 166, 'put': 165, 'live': 163, 'must': 163, 'news': 161, 'return': 161, 'feel': 161, 'target': 161, 'submit': 160, 'templ': 159, 'learn': 157, 'bill': 157, 'fact': 156, 'well': 156, 'info': 156, 'earn': 155, 'immedi': 155, 'assist': 155, 'share': 154, 'two': 153, 'tm': 153, 'total': 153, 'issu': 153, 'hundr': 153, 'limit': 152, 'allow': 152, 'weight': 151, 'enter': 151, 'debt': 151, 'contain': 150, 'subscrib': 150, 'tell': 150, 'effect': 149, 'databas': 149, 'plu': 148, 'present': 146, 'citi': 146, 'onc': 146, 'nation': 146, 'protect': 146, 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa': 146, 'promot': 145, 'thing': 145, 'regard':  ...

# %% [markdown]
# #### Extracting features

# %%
X_train, y_train = extract_features(train_directory,spam_vocabulary)

# %%
X_test , y_test = extract_features(test_directory,spam_vocabulary)

# %% [markdown]
# #### Fit the model and predict

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
model = SVC(C = 1, gamma = 0.01, kernel = 'linear')
model.fit(X_train,y_train)
res = model.predict(X_test)
print(confusion_matrix(y_test,res))
print(model.score(X_test,y_test))
# Out:
# [[274   9]
#  [  5 275]]
# 0.9751332149200711
